# %% [markdown]
# <a href="https://colab.research.google.com/github/arjundedge-tech/Colab/blob/main/datetime.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import datetime

hour = datetime.datetime.now().hour

if hour < 12:
    print("Good Morning Sir")
elif hour < 18:
    print("Good Afternoon Sir")
else:
    print("Good Evening Sir")
# Out:
# Good Morning Sir
