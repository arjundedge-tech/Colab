# %% [markdown]
# <a href="https://colab.research.google.com/github/arjundedge-tech/Colab/blob/main/breakcontinue.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
for i in range(1, 10):
    if i == 5:
        break        # stops the loop entirely
    print(i)

for i in range(1, 10):
    if i % 2 == 0:
        continue     # skips this iteration only
    print(i)
# Out:
# 1
# 2
# 3
# 4
# 1
# 3
# 5
# 7
# 9
