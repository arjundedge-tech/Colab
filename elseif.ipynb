# %% [markdown]
# <a href="https://colab.research.google.com/github/arjundedge-tech/Colab/blob/main/elseif.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
marks = 86

if marks >= 90:
    print("Grade A+")
elif marks >= 75:
    print("Grade A")
elif marks >= 60:
    print("Grade B")
else:
    print("Grade C")
# Out:
# Grade A
