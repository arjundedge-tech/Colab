# %% [markdown]
# <a href="https://colab.research.google.com/github/arjundedge-tech/Colab/blob/main/userinput.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
name = input("What is your name? ")
age = int(input("What is your age? "))   # cast to int since input() always returns a string

print(f"Hello {name}, you are {age} years old.")
# Out:
# What is your name? Arjun Dedge
# What is your age? 20
# Hello Arjun Dedge, you are 20 years old.
