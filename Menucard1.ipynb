# %% [markdown]
# <a href="https://colab.research.google.com/github/arjundedge-tech/Colab/blob/main/Menucard1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("Golden Cafe")
menu={"pizza":199, "sandwich":99, "cold coffee":49, "hot coffee":29, "burger":149,}
print(menu)
item=input("enter item")
print("you've ordered:", item)
total=0
while item !="done":
  total+=menu[item]
  item=input("enter item")
  print(total)
  if total>300:
    print("price after discount")
    print(total-(total*20/100))
  else:
    print("sorry, no discount", total)
# Out:
# Golden Cafe
# {'pizza': 199, 'sandwich': 99, 'cold coffee': 49, 'hot coffee': 29, 'burger': 149}
# enter itempizza
# you've ordered: pizza
# enter itemsandwich
# 199
# sorry, no discount 199
# enter itemcold coffee
# 298
# sorry, no discount 298
# enter itemdone
# 347
# price after discount
# 277.6
